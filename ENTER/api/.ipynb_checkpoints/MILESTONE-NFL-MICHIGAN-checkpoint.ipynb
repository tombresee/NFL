# %% [markdown]
# * https://www.kaggle.com/paultimothymooney/exploring-the-kaggle-api

# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
from PIL import Image
from IPython.core import display as ICD
# %matplotlib inline
def convert_to_df(csv): # needs to be repaired
    df = pd.DataFrame(data=csv)[0].str.split(',',expand=True)  
    header = df.iloc[0]
    df = df[1:]
    df.columns = header
    return df

# %%
# If you are using a local machine you will need to create a JSON metadata file containing your USER_ID and USER_SECRET (  ~/.kaggle/kaggle.json) 
# and likewise if you are creating a dataset or a kernel each dataset or kernel will need to be paired with a custom JSON metadata file.  
# More information on creating JSON metadata files can be found in the official documentation ([Link #1](https://github.com/Kaggle/kaggle-api#api-credentials), [Link #2](https://github.com/Kaggle/kaggle-api/wiki/Dataset-Metadata), [Link #3](https://github.com/Kaggle/kaggle-api/wiki/Kernel-Metadata)) 
# but for the sake of portability we will create these JSON metadata files and we will perform all other computations within the Kaggle Kernel itself.  
# Note that the user_secret is tied to a specific user_id and can be accessed from within the "Account" tab on your Kaggle profile by clicking on the "Create New API Key" button. 


# begin secret_api_token code so that nobody steals my API token.  
# Remove this section after forking this kernel.

from shutil import copyfile
copyfile(src = "../input/private_kaggle_api_token.py", dst = "../working/private_kaggle_api_token.py")

from private_kaggle_api_token import *

private_kaggle_api_token = private_kaggle_api_token()

# end secret_api_token code that hopefully prevents people from stealing my API token.  Remove this section after forking this kernel.

# Create a JSON file containing user-specific metadata. 
# This step is required if you want to access the Kaggle API.  
# For more info see: https://github.com/Kaggle/kaggle-api#api-credentials
USER_ID = 'paultimothymooney' # REPLACE WITH YOUR OWN USER NAME
USER_SECRET = private_kaggle_api_token # REPLACE WITH YOUR OWN PRIVATE API TOKEN
import os, json, nbformat, pandas as pd
KAGGLE_CONFIG_DIR = os.path.join(os.path.expandvars('$HOME'), '.kaggle')
os.makedirs(KAGGLE_CONFIG_DIR, exist_ok = True)
with open(os.path.join(KAGGLE_CONFIG_DIR, 'kaggle.json'), 'w') as f:
    json.dump({'username': USER_ID, 'key': USER_SECRET}, f)
# !chmod 600 {KAGGLE_CONFIG_DIR}/kaggle.json
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-00291557b028> in <module>
#      10
#      11 from shutil import copyfile
# ---> 12 copyfile(src = "../input/private_kaggle_api_token.py", dst = "../working/private_kaggle_api_token.py")
#      13
#      14 from private_kaggle_api_token import *
#
# ~\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/private_kaggle_api_token.py'

# %%
# !kaggle competitions list --csv
# Out:
# ref,deadline,category,reward,teamCount,userHasEntered
#
# contradictory-my-dear-watson,2030-07-01 23:59:00,Getting Started,Prizes,81,False
#
# gan-getting-started,2030-07-01 23:59:00,Getting Started,Prizes,172,False
#
# tpu-getting-started,2030-06-03 23:59:00,Getting Started,Knowledge,263,False
#
# digit-recognizer,2030-01-01 00:00:00,Getting Started,Knowledge,2333,False
#
# titanic,2030-01-01 00:00:00,Getting Started,Knowledge,17717,True
#
# house-prices-advanced-regression-techniques,2030-01-01 00:00:00,Getting Started,Knowledge,4534,True
#
# connectx,2030-01-01 00:00:00,Getting Started,Knowledge,416,False
#
# nlp-getting-started,2030-01-01 00:00:00,Getting Started,Knowledge,1230,False
#
# competitive-data-science-predict-future-sales,2022-12-31 23:59:00,Playground,Kudos,9656,False
#
# jane-street-market-prediction,2021-02-22 23:59:00,Featured,"$100,000",376,False
#
# cassava-leaf-disease-classification,2021-02-18 23:59:00,Research,"$18,000",627,False
#
# rfcx-species-audio-detection,2021-02-17 23:59:00,Research,"$15,000",219,False
#
# rock-paper-scissors,2021-02-01 23:59:00,Playground,Prizes,901,False
#
# hubmap-kidney-segmentation,2021-02-01 23:59:00,Research,"$60,000",136,False
#
# riiid-test-answer-prediction,2021-01-07 23:59:00,Featured,"$100,000",2097,False
#
# kaggle-survey-2020,2021-01-06 23:59:00,Analytics,"$30,000",0,False
#
# nfl-big-data-bowl-2021,2021-01-05 23:59:00,Analytics,"$100,000",0,True
#
# nfl-impact-detection,2021-01-04 23:59:00,Featured,"$75,000",23,False
#
# halite-iv-playground-edition,2020-12-31 23:59:00,Playground,Knowledge,53,False
#
# predict-volcanic-eruptions-ingv-oe,2020-12-28 23:59:00,Playground,Swag,326,False

# %%
competitions_list_csv = !kaggle competitions list --csv
competitions_list_df = convert_to_df(competitions_list_csv)
print('20 Competitions from Kaggle.com/competitions:')
ICD.display(competitions_list_df.head(10))
# Out:
# 20 Competitions from Kaggle.com/competitions:
# 0                            ref             deadline         category  \
# 1                                                None             None
# 2   contradictory-my-dear-watson  2030-07-01 23:59:00  Getting Started
# 3                                                None             None
# 4            gan-getting-started  2030-07-01 23:59:00  Getting Started
# 5                                                None             None
# 6            tpu-getting-started  2030-06-03 23:59:00  Getting Started
# 7                                                None             None
# 8               digit-recognizer  2030-01-01 00:00:00  Getting Started
# 9                                                None             None
# 10                       titanic  2030-01-01 00:00:00  Getting Started
#
# 0      reward teamCount userHasEntered   NaN
# 1        None      None           None  None
# 2      Prizes        81          False  None
# 3        None      None           None  None
# 4      Prizes       172          False  None
# 5        None      None           None  None
# 6   Knowledge       263          False  None
# 7        None      None           None  None
# 8   Knowledge      2333          False  None
# 9        None      None           None  None
# 10  Knowledge     17717           True  None

# %%
digit_recognizer_search_in_competitions_csv = !kaggle competitions list -s digit-recognizer --csv
digit_recognizer_search_in_competitions_df = convert_to_df(digit_recognizer_search_in_competitions_csv)
print('Search Results for Digit-Recognizer Competition:')
ICD.display(digit_recognizer_search_in_competitions_df.head(10))
# Out:
# Search Results for Digit-Recognizer Competition:
# 0                ref             deadline         category     reward  \
# 1                                    None             None       None
# 2   digit-recognizer  2030-01-01 00:00:00  Getting Started  Knowledge
# 3                                    None             None       None
# 4   GestureChallenge  2012-04-10 23:59:59         Featured       "$10
# 5                                    None             None       None
# 6  GestureChallenge2  2012-09-11 23:59:00         Research       "$10
# 7                                    None             None       None
#
# 0 teamCount userHasEntered    NaN
# 1      None           None   None
# 2      2333          False   None
# 3      None           None   None
# 4      000"             47  False
# 5      None           None   None
# 6      000"             30  False
# 7      None           None   None

# %%
leaderboard_list_csv = !kaggle competitions leaderboard digit-recognizer -s --csv
leaderboard_list_df = convert_to_df(leaderboard_list_csv)
print('Leaderboard for MNIST Competition:')
ICD.display(leaderboard_list_df.head(10))
# Out:
# Leaderboard for MNIST Competition:
# 0    teamId             teamName       submissionDate    score
# 1                           None                 None     None
# 2   5535376  Prakhar Singh Tomar  2020-09-29 11:16:19  1.00000
# 3                           None                 None     None
# 4    598353      Jerome Blanchet  2020-09-29 14:35:25  1.00000
# 5                           None                 None     None
# 6   5592247    Phaneendhar Thota  2020-10-16 19:30:05  1.00000
# 7                           None                 None     None
# 8   5580167     JasonZhuang19241  2020-09-29 23:25:46  1.00000
# 9                           None                 None     None
# 10  5594898    Abdolkarim Saeedi  2020-09-30 08:43:53  1.00000

# %%
datasets_list_csv = !kaggle datasets list --csv
datasets_list_df = convert_to_df(datasets_list_csv)
print('20 Datasets from Kaggle.com/datasets:')
datasets_list_df_sorted = datasets_list_df.sort_values(by='lastUpdated', ascending=0)
ICD.display(datasets_list_df_sorted.head(10))
# Out:
# 20 Datasets from Kaggle.com/datasets:
# 0                                                 ref  \
# 24  antgoldbloom/covid19-data-from-john-hopkins-un...
# 20                          unanimad/us-election-2020
# 8       imoore/2020-us-general-election-turnout-rates
# 14               arioboo/clumps-in-vela-galaxy-images
# 18              mrmorj/us-politicians-twitter-dataset
# 16         patrickb1912/ipl-complete-dataset-20082020
# 10  alexgude/california-traffic-collision-data-fro...
# 12                              afrniomelo/3w-dataset
# 4   szymonjanowski/internet-articles-data-with-use...
# 2      babyoda/women-entrepreneurship-and-labor-force
#
# 0                                           title   size          lastUpdated  \
# 24     COVID-19 data from John Hopkins University    3MB  2020-11-27 06:04:08
# 20                               US Election 2020  430KB  2020-11-26 12:57:22
# 8          2020 US General Election Turnout rates    4KB  2020-11-26 00:21:15
# 14                   Clumps in VELA galaxy images    8MB  2020-11-23 13:42:09
# 18                 US Politicians Twitter Dataset   68KB  2020-11-23 09:54:05
# 16               IPL Complete Dataset (2008-2020)    1MB  2020-11-23 06:53:37
# 10  California Traffic Collision Data from SWITRS    1GB  2020-11-22 16:51:55
# 12   3W Dataset - Undesirable events in oil wells  658MB  2020-11-21 21:22:49
# 4      Internet news data with readers engagement    3MB  2020-11-21 17:09:57
# 2          Women Entrepreneurship and Labor Force    1KB  2020-11-21 08:38:51
#
# 0  downloadCount voteCount usabilityRating
# 24          5053       170       0.9705882
# 20          9344       389             1.0
# 8            538        44             1.0
# 14            44         9       0.7058824
# 18           131         5             1.0
# 16           404        14       0.9705882
# 10           151        14       0.9705882
# 12            59         5          0.8125
# 4            352        21       0.9411765
# 2            896        64             1.0

# %%
fashion_minst_search_in_datasets_csv = !kaggle datasets list -s fashion-mnist --csv
fashion_minst_search_in_datasets_df = convert_to_df(fashion_minst_search_in_datasets_csv)
print('Search Results for Fashion-MNIST Dataset:')
ICD.display(fashion_minst_search_in_datasets_df.head(10))
# Out:
# Search Results for Fashion-MNIST Dataset:
# 0                                            ref  \
# 1
# 2                  zalando-research/fashionmnist
# 3
# 4                  datamunge/sign-language-mnist
# 5
# 6   paramaggarwal/fashion-product-images-dataset
# 7
# 8     paramaggarwal/fashion-product-images-small
# 9
# 10                          qnkhuat/fashionmnist
#
# 0                            title   size          lastUpdated downloadCount  \
# 1                             None   None                 None          None
# 2                    Fashion MNIST   69MB  2017-12-07 00:54:20         77141
# 3                             None   None                 None          None
# 4              Sign Language MNIST   63MB  2017-10-20 15:09:18         33414
# 5                             None   None                 None          None
# 6   Fashion Product Images Dataset   23GB  2019-03-14 18:57:43          7648
# 7                             None   None                 None          None
# 8   Fashion Product Images (Small)  565MB  2019-04-26 16:33:51          5865
# 9                             None   None                 None          None
# 10                   fashion-mnist  140MB  2019-06-26 11:00:07            84
#
# 0  voteCount usabilityRating
# 1       None            None
# 2       1579      0.85294116
# 3       None            None
# 4        811       0.7647059
# 5       None            None
# 6        166       0.5882353
# 7       None            None
# 8        123       0.5882353
# 9       None            None
# 10         3          0.3125

# %%
# download fashion mnist dataset from Kaggle datasets platform
fashionmnist = os.path.join('.', 'working/fashionmnist')
os.makedirs(fashionmnist, exist_ok = True)
# !kaggle datasets download -d zalando-research/fashionmnist -p working/fashionmnist

# download digit recognizer dataset from Kaggle competitions platform
digitrecognizer = os.path.join('.', 'working/digitrecognizer')
os.makedirs(digitrecognizer, exist_ok = True)
# !kaggle competitions download digit-recognizer -p working/digitrecognizer
# Out:
# Downloading fashionmnist.zip to working/fashionmnist
#   0%|          | 0.00/68.8M [00:00<?, ?B/s]
#   1%|1         | 1.00M/68.8M [00:00<00:26, 2.70MB/s]
#   3%|2         | 2.00M/68.8M [00:00<00:21, 3.31MB/s]
#   4%|4         | 3.00M/68.8M [00:00<00:17, 3.88MB/s]
#   6%|5         | 4.00M/68.8M [00:00<00:16, 4.23MB/s]
#   7%|7         | 5.00M/68.8M [00:01<00:15, 4.42MB/s]
#   9%|8         | 6.00M/68.8M [00:01<00:13, 4.76MB/s]
#  10%|#         | 7.00M/68.8M [00:01<00:12, 5.25MB/s]
#  12%|#1        | 8.00M/68.8M [00:01<00:11, 5.40MB/s]
#  13%|#3        | 9.00M/68.8M [00:01<00:10, 5.72MB/s]
#  15%|#4        | 10.0M/68.8M [00:01<00:11, 5.51MB/s]
#  16%|#5        | 11.0M/68.8M [00:02<00:10, 5.79MB/s]
#  17%|#7        | 12.0M/68.8M [00:02<00:12, 4.95MB/s]
#  20%|##        | 14.0M/68.8M [00:02<00:09, 5.75MB/s]
#  22%|##1       | 15.0M/68.8M [00:02<00:10, 5.52MB/s]
#  23%|##3       | 16.0M/68.8M [00:03<00:09, 5.73MB/s]
#  25%|##4       | 17.0M/68.8M [00:03<00:08, 6.06MB/s]
#  26%|##6       | 18.0M/68.8M [00:03<00:08, 6.19MB/s]
#  28%|##7       | 19.0M/68.8M [00:03<00:08, 5.94MB/s]
#  29%|##9       | 20.0M/68.8M [00:03<00:08, 6.19MB/s]
#  31%|###       | 21.0M/68.8M [00:03<00:07, 6.33MB/s]
#  32%|###1      | 22.0M/68.8M [00:04<00:07, 6.44MB/s]
#  33%|###3      | 23.0M/68.8M [00:04<00:08, 5.88MB/s]
#  35%|###4      | 24.0M/68.8M [00:04<00:07, 6.06MB/s]
#  36%|###6      | 25.0M/68.8M [00:04<00:07, 5.78MB/s]
#  38%|###7      | 26.0M/68.8M [00:04<00:07, 6.05MB/s]
#  39%|###9      | 27.0M/68.8M [00:04<00:07, 5.61MB/s]
#  41%|####      | 28.0M/68.8M [00:05<00:07, 6.03MB/s]
#  42%|####2     | 29.0M/68.8M [00:05<00:07, 5.71MB/s]
#  44%|####3     | 30.0M/68.8M [00:05<00:07, 5.53MB/s]
#  45%|####5     | 31.0M/68.8M [00:05<00:06, 5.80MB/s]
#  47%|####6     | 32.0M/68.8M [00:05<00:06, 5.93MB/s]
#  48%|####7     | 33.0M/68.8M [00:06<00:06, 5.66MB/s]
#  49%|####9     | 34.0M/68.8M [00:06<00:06, 5.99MB/s]
#  51%|#####     | 35.0M/68.8M [00:06<00:05, 6.10MB/s]
#  52%|#####2    | 36.0M/68.8M [00:06<00:05, 6.32MB/s]
#  54%|#####3    | 37.0M/68.8M [00:06<00:05, 5.81MB/s]
#  55%|#####5    | 38.0M/68.8M [00:06<00:05, 6.06MB/s]
#  57%|#####6    | 39.0M/68.8M [00:07<00:05, 6.08MB/s]
#  58%|#####8    | 40.0M/68.8M [00:07<00:04, 6.35MB/s]
#  60%|#####9    | 41.0M/68.8M [00:07<00:04, 5.84MB/s]
#  61%|######1   | 42.0M/68.8M [00:07<00:04, 5.74MB/s]
#  63%|######2   | 43.0M/68.8M [00:07<00:04, 5.81MB/s]
#  64%|######3   | 44.0M/68.8M [00:07<00:04, 6.13MB/s]
#  65%|######5   | 45.0M/68.8M [00:08<00:04, 5.62MB/s]
#  67%|######6   | 46.0M/68.8M [00:08<00:04, 5.77MB/s]
#  68%|######8   | 47.0M/68.8M [00:08<00:03, 5.97MB/s]
#  70%|######9   | 48.0M/68.8M [00:08<00:03, 6.29MB/s]
#  71%|#######1  | 49.0M/68.8M [00:08<00:03, 6.47MB/s]
#  73%|#######2  | 50.0M/68.8M [00:08<00:03, 6.01MB/s]
#  74%|#######4  | 51.0M/68.8M [00:09<00:02, 6.37MB/s]
#  76%|#######5  | 52.0M/68.8M [00:09<00:02, 6.13MB/s]
#  77%|#######7  | 53.0M/68.8M [00:09<00:02, 6.01MB/s]
#  79%|#######8  | 54.0M/68.8M [00:09<00:02, 6.13MB/s]
#  80%|#######9  | 55.0M/68.8M [00:09<00:02, 6.19MB/s]
#  81%|########1 | 56.0M/68.8M [00:10<00:02, 5.56MB/s]
#  83%|########2 | 57.0M/68.8M [00:10<00:02, 5.66MB/s]
#  84%|########4 | 58.0M/68.8M [00:10<00:02, 5.64MB/s]
#  86%|########5 | 59.0M/68.8M [00:10<00:02, 4.23MB/s]
#  87%|########7 | 60.0M/68.8M [00:10<00:01, 4.66MB/s]
#  89%|########8 | 61.0M/68.8M [00:11<00:01, 5.05MB/s]
#  90%|######### | 62.0M/68.8M [00:11<00:01, 5.05MB/s]
#  92%|#########1| 63.0M/68.8M [00:11<00:01, 5.32MB/s]
#  93%|#########3| 64.0M/68.8M [00:11<00:00, 5.94MB/s]
#  95%|#########4| 65.0M/68.8M [00:11<00:00, 5.72MB/s]
#  96%|#########5| 66.0M/68.8M [00:12<00:00, 5.92MB/s]
#  97%|#########7| 67.0M/68.8M [00:12<00:00, 6.18MB/s]
#  99%|#########8| 68.0M/68.8M [00:12<00:00, 6.30MB/s]
# 100%|##########| 68.8M/68.8M [00:12<00:00, 6.14MB/s]
# 100%|##########| 68.8M/68.8M [00:12<00:00, 5.79MB/s]
# Downloading digit-recognizer.zip to working/digitrecognizer
#   0%|          | 0.00/15.3M [00:00<?, ?B/s]
#   7%|6         | 1.00M/15.3M [00:00<00:03, 3.78MB/s]
#  13%|#3        | 2.00M/15.3M [00:00<00:03, 4.20MB/s]
#  20%|#9        | 3.00M/15.3M [00:00<00:02, 4.62MB/s]
#  26%|##6       | 4.00M/15.3M [00:00<00:02, 5.15MB/s]
#  33%|###2      | 5.00M/15.3M [00:00<00:01, 5.52MB/s]
#  39%|###9      | 6.00M/15.3M [00:01<00:01, 5.61MB/s]
#  46%|####5     | 7.00M/15.3M [00:01<00:01, 5.68MB/s]
#  52%|#####2    | 8.00M/15.3M [00:01<00:01, 6.01MB/s]
#  59%|#####8    | 9.00M/15.3M [00:01<00:01, 5.99MB/s]
#  65%|######5   | 10.0M/15.3M [00:01<00:00, 6.19MB/s]
#  72%|#######1  | 11.0M/15.3M [00:01<00:00, 6.48MB/s]
#  78%|#######8  | 12.0M/15.3M [00:02<00:00, 6.56MB/s]
#  85%|########4 | 13.0M/15.3M [00:02<00:00, 6.66MB/s]
#  91%|#########1| 14.0M/15.3M [00:02<00:00, 6.52MB/s]
#  98%|#########7| 15.0M/15.3M [00:02<00:00, 6.45MB/s]
# 100%|##########| 15.3M/15.3M [00:02<00:00, 6.14MB/s]

# %%
data = pd.read_csv('working/digitrecognizer/train.csv')
testingData = pd.read_csv('working/digitrecognizer/test.csv')
X = data.drop("label",axis=1).values
y = data.label.values

def describeDataset(features,labels):
    print("\n'X' shape: %s."%(features.shape,))
    print("\n'y' shape: %s."%(labels.shape,))
    print("\nUnique elements in y: %s"%(np.unique(y)))
describeDataset(X,y)

def displayMNIST(flatData,labels):
    """ Displays 10 handwritten digis and 10 classification labels """
    figure,image = plt.subplots(1,10, figsize=(10,10))
    for i in range(10):
        image[i].imshow(flatData[i].reshape((28,28)))
        image[i].axis('off')
        image[i].set_title(labels[i])
displayMNIST(X,y)

def displayMNIST2(flatData,labels):
    """Display MNIST data"""
    flatData2 = data.drop("label",axis=1).values
    X2 = np.insert(flatData2,0,1,axis=1)
    figure,image = plt.subplots(1,10, figsize=(10,10))
    for i in range(10):
        tenImages = np.random.choice(X2.shape[0], 10)
        image[i].imshow(X2[tenImages,1:].reshape(-1,28))
        image[i].axis('off')
displayMNIST2(X,y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-3cbaddbed5fb> in <module>
# ----> 1 data = pd.read_csv('working/digitrecognizer/train.csv')
#       2 testingData = pd.read_csv('working/digitrecognizer/test.csv')
#       3 X = data.drop("label",axis=1).values
#       4 y = data.label.values
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'working/digitrecognizer/train.csv'

# %%
kernel_listings_csv = !kaggle kernels list -s kaggle-kernel-demo --csv
kernel_listings_df = convert_to_df(kernel_listings_csv)
print('Listing of Kernels on Kaggle for Search Term "Demo":')
ICD.display(kernel_listings_df.head(10))
# Out:
# Listing of Kernels on Kaggle for Search Term "Demo":
# 0                                                ref  \
# 1
# 2  paultimothymooney/kaggle-kernel-demo-pre-train...
# 3
# 4     richardsun72/demo-how-to-use-kaggle-kernel-knn
# 5
# 6  dazcode/kaggle-kernel-demo-pre-trained-image-c...
# 7
#
# 0                                              title       author  \
# 1                                               None         None
# 2   Kaggle Kernel Demo: Pre-trained Image Classifier  Paul Mooney
# 3                                               None         None
# 4                     "Demo how to use Kaggle Kernel         KNN"
# 5                                               None         None
# 6  Kaggle Kernel Demo: Pre-trained Image Class 91...      dazcode
# 7                                               None         None
#
# 0          lastRunTime           totalVotes   NaN
# 1                 None                 None  None
# 2  2018-07-19 21:54:30                    5  None
# 3                 None                 None  None
# 4          Richard Sun  2018-04-08 03:34:41     1
# 5                 None                 None  None
# 6  2018-10-20 09:15:30                    0  None
# 7                 None                 None  None

# %%
# Create a JSON file containing kernel-specific metadata
# https://github.com/Kaggle/kaggle-api/wiki/Kernel-Metadata
notebook_meta_template = lambda user_id, title, file_id, nb_path: {'id': f'{user_id}/{file_id}',
 'title': f'{title}',
 'code_file': nb_path,
 'language': 'python',
 'kernel_type': 'notebook',
 'is_private': True,
 'enable_gpu': True,
 'enable_internet': False,
 'keywords': [],
 'dataset_sources': ['keras/resnet50', 'paultimothymooney/sample-images-for-kaggle-demos'],
 'kernel_sources': [],
 'competition_sources': []}

name_of_new_kernel='Kaggle-Kernel-Demo-From-API'
path_of_current_kernel = 'working/demokernel/kaggle-kernel-demo-pre-trained-image-classifier.ipynb'
with open('kernel-metadata.json', 'w') as f:
    meta_dict = notebook_meta_template(USER_ID,name_of_new_kernel,name_of_new_kernel,path_of_current_kernel)
    json.dump(meta_dict, f)
    
# download kaggle kernel demo
demokernel = os.path.join('.', 'working/demokernel')
os.makedirs(demokernel, exist_ok = True)
# !kaggle kernels pull paultimothymooney/kaggle-kernel-demo-pre-trained-image-classifier -p working/demokernel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-66d1791cc0b6> in <module>
#      17 path_of_current_kernel = 'working/demokernel/kaggle-kernel-demo-pre-trained-image-classifier.ipynb'
#      18 with open('kernel-metadata.json', 'w') as f:
# ---> 19     meta_dict = notebook_meta_template(USER_ID,name_of_new_kernel,name_of_new_kernel,path_of_current_kernel)
#      20     json.dump(meta_dict, f)
#      21
#
# NameError: name 'USER_ID' is not defined

# %%
# !zip -r kerasmnist.zip working/kerasmnist/
# !zip -r demokernel.zip working/demokernel/
# !rm -rf working/*
# !rm -r working
# !rm -r kernel-metadata.json
# !rm -r dataset-metadata.json
# !rm -r private_kaggle_api_token.py
# !rm -r __pycache__/private_kaggle_api_token.cpython-36.pyc # Please dont steal my token
